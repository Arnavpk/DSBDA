# %%
text = """
Natural Language Processing (NLP) is a field of Artificial Intelligence.
It helps computers understand human language and process text efficiently.
"""

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', 'and', 'process', 'text', 'efficiently', '.']

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag

pos_tags = pos_tag(tokens)
print(pos_tags)
# Out:
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('field', 'NN'), ('of', 'IN'), ('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ'), ('language', 'NN'), ('and', 'CC'), ('process', 'NN'), ('text', 'NN'), ('efficiently', 'RB'), ('.', '.')]

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print(filtered_tokens)
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'Artificial', 'Intelligence', '.', 'helps', 'computers', 'understand', 'human', 'language', 'process', 'text', 'efficiently', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words)
# Out:
# ['natur', 'languag', 'process', '(', 'nlp', ')', 'field', 'artifici', 'intellig', '.', 'help', 'comput', 'understand', 'human', 'languag', 'process', 'text', 'effici', '.']

# %%
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/arnavkulkarni/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'Artificial', 'Intelligence', '.', 'help', 'computer', 'understand', 'human', 'language', 'process', 'text', 'efficiently', '.']

# %%
from collections import Counter

tf = Counter(filtered_tokens)
print(tf)
# Out:
# Counter({'.': 2, 'Natural': 1, 'Language': 1, 'Processing': 1, '(': 1, 'NLP': 1, ')': 1, 'field': 1, 'Artificial': 1, 'Intelligence': 1, 'helps': 1, 'computers': 1, 'understand': 1, 'human': 1, 'language': 1, 'process': 1, 'text': 1, 'efficiently': 1})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [text]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
print(tfidf_matrix.toarray())
# Out:
# ['and' 'artificial' 'computers' 'efficiently' 'field' 'helps' 'human'
#  'intelligence' 'is' 'it' 'language' 'natural' 'nlp' 'of' 'process'
#  'processing' 'text' 'understand']
# [[0.21821789 0.21821789 0.21821789 0.21821789 0.21821789 0.21821789
#   0.21821789 0.21821789 0.21821789 0.21821789 0.43643578 0.21821789
#   0.21821789 0.21821789 0.21821789 0.21821789 0.21821789 0.21821789]]
